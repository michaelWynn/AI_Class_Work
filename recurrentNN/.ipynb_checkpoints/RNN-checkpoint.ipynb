# %%
# !pip3 install --upgrade tensorflow
# !pip3 install keras
# Out:
# Requirement already up-to-date: tensorflow in c:\users\wynnm\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied, skipping upgrade: absl-py~=0.10 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (0.11.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing~=1.1.2 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied, skipping upgrade: h5py~=2.10.0 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied, skipping upgrade: numpy~=1.19.2 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (1.19.2)
# Requirement already satisfied, skipping upgrade: typing-extensions~=3.7.4 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.5.0,>=2.4.0 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied, skipping upgrade: wrapt~=1.12.1 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied, skipping upgrade: protobuf>=3.9.2 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied, skipping upgrade: termcolor~=1.1.0 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied, skipping upgrade: grpcio~=1.32.0 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (1.32.0)
# Requirement already satisfied, skipping upgrade: flatbuffers~=1.12.0 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied, skipping upgrade: opt-einsum~=3.3.0 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied, skipping upgrade: google-pasta~=0.2 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied, skipping upgrade: astunparse~=1.6.3 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied, skipping upgrade: six~=1.15.0 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied, skipping upgrade: tensorboard~=2.4 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (2.4.1)
# Requirement already satisfied, skipping upgrade: wheel~=0.35 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (0.35.1)
# Requirement already satisfied, skipping upgrade: gast==0.3.3 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (3.3.3)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.8.0)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.26.1)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (2.24.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.0.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\wynnm\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (0.4.2)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\wynnm\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.7.1)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in c:\users\wynnm\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\users\wynnm\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\wynnm\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\wynnm\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.25.11)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\wynnm\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\wynnm\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.6.20)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in c:\users\wynnm\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in c:\users\wynnm\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in c:\users\wynnm\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.1.0)
# Requirement already satisfied: keras in c:\users\wynnm\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\wynnm\anaconda3\lib\site-packages (from keras) (1.19.2)
# Requirement already satisfied: pyyaml in c:\users\wynnm\anaconda3\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: h5py in c:\users\wynnm\anaconda3\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in c:\users\wynnm\anaconda3\lib\site-packages (from keras) (1.5.2)
# Requirement already satisfied: six in c:\users\wynnm\anaconda3\lib\site-packages (from h5py->keras) (1.15.0)

# %%
import numpy as np

from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

INPUT_FILE = 'alice-in-wonderland.txt'

# %%
print('Extracting text from input')
file = open(INPUT_FILE, 'rb')
lines = []
for line in file:
    line = line.strip().lower()
    line = line.decode('ascii', 'ignore')
    if len(line) == 0:
        continue
    lines.append(line)
file.close()
text = ' '.join(lines)
# Out:
# Extracting text from input

# %%
chars = set([c for c in text])
nb_chars = len(chars)
char2index = dict((c, i) for i, c in enumerate(chars))
index2char = dict((i, c) for i, c in enumerate(chars))

print(index2char)
# Out:
# {0: 'b', 1: ',', 2: 'i', 3: "'", 4: '@', 5: '9', 6: '$', 7: 'n', 8: 'g', 9: 'd', 10: 'h', 11: 'y', 12: 'k', 13: '6', 14: '4', 15: '8', 16: 'a', 17: '.', 18: ' ', 19: '7', 20: 'w', 21: '%', 22: 'u', 23: 't', 24: 'p', 25: '_', 26: 'e', 27: '*', 28: '3', 29: ':', 30: '#', 31: '"', 32: '0', 33: '/', 34: '[', 35: ';', 36: '?', 37: 'x', 38: 'l', 39: '5', 40: '!', 41: 'f', 42: 'v', 43: 'r', 44: 'z', 45: '2', 46: '(', 47: ')', 48: 'q', 49: 'm', 50: '-', 51: ']', 52: 'j', 53: 'c', 54: 's', 55: 'o', 56: '1'}

# %%
print('Creating input and label')
SEQ_LEN = 10
STEP = 1
print('The table is ready')
# Out:
# Creating input and label
# The table is ready

# %%
input_chars = []
label_chars = []
for i in range(0, len(text) - SEQ_LEN, STEP):
    input_chars.append(text[i:i + SEQ_LEN])
    label_chars.append(text[i + SEQ_LEN])

print(input_chars)
# Out:
# ['project gu', 'roject gut', 'oject gute', 'ject guten', 'ect gutenb', 'ct gutenbe', 't gutenber', ' gutenberg', "gutenberg'", "utenberg's", "tenberg's ", "enberg's a", "nberg's al", "berg's ali", "erg's alic", "rg's alice", "g's alice'", "'s alice's", "s alice's ", " alice's a", "alice's ad", "lice's adv", "ice's adve", "ce's adven", "e's advent", "'s adventu", 's adventur', ' adventure', 'adventures', 'dventures ', 'ventures i', 'entures in', 'ntures in ', 'tures in w', 'ures in wo', 'res in won', 'es in wond', 's in wonde', ' in wonder', 'in wonderl', 'n wonderla', ' wonderlan', 'wonderland', 'onderland,', 'nderland, ', 'derland, b', 'erland, by', 'rland, by ', 'land, by l', 'and, by le', 'nd, by lew', 'd, by lewi', ', by lewis', ' by lewis ', 'by lewis c', 'y lewis ca', ' lewis car', 'lewis carr', 'ewis carro', 'wis carrol', 'is carroll', 's carroll ', ' carroll t', 'carroll th', 'arroll thi', 'rroll this', 'roll this ', 'oll this e', 'll this eb', 'l this ebo', ' this eboo', 'this ebook', 'his ebook ', 'is ebook i', 's ebook is', ' ebook is ', 'ebook is f', 'book is fo', 'ook is for', 'ok is for ', 'k is for t', ' is for th', 'is for the', 's for the ', ' for the u', 'for the us', 'or the use', 'r the use ', ' the use o', 'the use of', 'he use of ', 'e use of a', ' use of an', 'use of any', 'se of anyo', 'e of anyon', ' of anyone', 'of anyone ', 'f anyone a', ' anyone an', 'anyone any', 'nyone anyw', 'yone anywh', 'one anywhe', 'ne anywher', 'e anywhere', ' anywhere ', 'anywhere a', 'nywhere at', 'ywhere at ', 'where at n', 'here at no', 'ere at no ', 're at no c', 'e at no co', ' at no cos', 'at no cost', 't no cost ', ' no cost a', 'no cost an', 'o cost and', ' cost and ', 'cost and w', 'ost and wi', 'st and wit', 't and with', ' and with ', 'and with a', 'nd with al', 'd with alm', ' with almo', 'with almos', 'ith almost', 'th almost ', 'h almost n', ' almost no', 'almost no ', 'lmost no r', 'most no re', 'ost no res', 'st no rest', 't no restr', ' no restri', 'no restric', 'o restrict', ' restricti', 'restrictio', 'estriction', 'strictions', 'trictions ', 'rictions w', 'ictions wh', 'ctions wha', 'tions what', 'ions whats', 'ons whatso', 'ns whatsoe', 's whatsoev', ' whatsoeve', 'whatsoever', 'hatsoever.', 'atsoever. ', 'tsoever.  ', 'soever.  y', 'oever.  yo', 'ever.  you', 'ver.  you ', 'er.  you m', 'r.  you ma', '.  you may', '  you may ', ' you may c', 'you may co', 'ou may cop', 'u may copy', ' may copy ', 'may copy i', 'ay copy it', 'y copy it,', ' copy it, ', 'copy it, g', 'opy it, gi', 'py it, giv', 'y it, give', ' it, give ', 'it, give i', 't, give it', ', give it ', ' give it a', 'give it aw', 'ive it awa', 've it away', 'e it away ', ' it away o', 'it away or', 't away or ', ' away or r', 'away or re', 'way or re-', 'ay or re-u', 'y or re-us', ' or re-use', 'or re-use ', 'r re-use i', ' re-use it', 're-use it ', 'e-use it u', '-use it un', 'use it und', 'se it unde', 'e it under', ' it under ', 'it under t', 't under th', ' under the', 'under the ', 'nder the t', 'der the te', 'er the ter', 'r the term', ' the terms', 'the terms ', 'he terms o', 'e terms of', ' terms of ', 'terms of t', 'erms of th', 'rms of the', 'ms of the ', 's of the p', ' of the pr', 'of the pro', 'f the proj', ' the proje', 'the projec', 'he project', 'e project ', ' project g', 'project gu', 'roject gut', 'oject gute', 'ject guten', 'ect gutenb', 'ct gutenbe', 't gutenber', ' gutenberg', 'gutenberg ', 'utenberg l', 'tenberg li', 'enberg lic', 'nberg lice', 'berg licen', 'erg licens', 'rg license', 'g license ', ' license i', 'license in', 'icense inc', 'cense incl', 'ense inclu', 'nse includ', 'se include', 'e included', ' included ', 'included w', 'ncluded wi', 'cluded wit', 'luded with', 'uded with ', 'ded with t', 'ed with th', 'd with thi', ' with this', 'with this ', 'ith this e', 'th this eb', 'h this ebo', ' this eboo', 'this ebook', 'his ebook ', 'is ebook o', 's ebook or', ' ebook or ', 'ebook or o', 'book or on', 'ook or o ...

# %%
print("Vectorizing input and label text...")
x = np.zeros((len(input_chars), SEQ_LEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)

for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        x[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1
# Out:
# Vectorizing input and label text...

# %%
HIDDEN_SIZE = 128
BATCH_SIZE = 128
NUM_ITERATIONS = 25
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100

model = Sequential()
model.add(SimpleRNN(HIDDEN_SIZE, return_sequences=False,
                    input_shape=(SEQ_LEN, nb_chars),
                    unroll=True))
model.add(Dense(nb_chars))
model.add(Activation("softmax"))

model.compile(loss="categorical_crossentropy", optimizer="rmsprop")

# %%
for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model.fit(x, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    
    # testing model
    # randomly choose a row from input_chars
    # generate text from model for next 100 chars
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]
    print("Generating from seed: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):
        xtest = np.zeros((1, SEQ_LEN, nb_chars))
        for i, ch in enumerate(test_chars):
            xtest[0, i, char2index[ch]] = 1
        pred = model.predict(xtest, verbose=0)[0]
        ypred = index2char[np.argmax(pred)]
        print(ypred, end="")
        # move forward with test_chars + ypred
        test_chars = test_chars[1:] + ypred
    print()
# Out:
# ==================================================
# Iteration #: 0
# 1264/1264 [==============================] - 8s 5ms/step - loss: 2.6226
# Generating from seed: jaws are t
# jaws are the the said the said the said the said the said the said the said the said the said the said the sai
# ==================================================
# Iteration #: 1
# 1264/1264 [==============================] - 6s 4ms/step - loss: 2.0672
# Generating from seed: ll me that
# ll me that the marthe the har here the the her alle the the her alle the the her alle the the her alle the the
# ==================================================
# Iteration #: 2
# 1264/1264 [==============================] - 6s 4ms/step - loss: 1.9649
# Generating from seed:  those tar
#  those tare the was so the was her hat her har head the moure so the was her hat her har head the moure so the
# ==================================================
# Iteration #: 3
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.8834
# Generating from seed: se directl
# se directle the had the growher gote the was so the was so the was so the was so the was so the was so the was
# ==================================================
# Iteration #: 4
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.8153
# Generating from seed: zy thing!'
# zy thing!' said the doust of the dored and the dored and the dored and the dored and the dored and the dored a
# ==================================================
# Iteration #: 5
# 1264/1264 [==============================] - 6s 4ms/step - loss: 1.7598
# Generating from seed:  his toes.
#  his toes. 'i mad to the work out of the word and the was souse on the was souse on the was souse on the was s
# ==================================================
# Iteration #: 6
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.7129
# Generating from seed: ing to end
# ing to ender the read the doom the she said the dormouse the she said the dormouse the she said the dormouse t
# ==================================================
# Iteration #: 7
# 1264/1264 [==============================] - 7s 5ms/step - loss: 1.6738
# Generating from seed: fund set f
# fund set for of the gryphon in a come the coure the gryphon in a come the coure the gryphon in a come the cour
# ==================================================
# Iteration #: 8
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.6397
# Generating from seed:  it goes o
#  it goes of the course for the project gutenberg-tm eres of the course for the project gutenberg-tm eres of th
# ==================================================
# Iteration #: 9
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.6106
# Generating from seed: ht poor al
# ht poor alice the dicelf enter as she was goon the mock turtle the mock turtle the mock turtle the mock turtle
# ==================================================
# Iteration #: 10
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.5854
# Generating from seed: ally takes
# ally takes the was a little so she said to herself the tore the looked again a serped the mouse of the sares o
# ==================================================
# Iteration #: 11
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.5619
# Generating from seed:  the duche
#  the duches ereat of the some to she said to her eneed to see thing in a lowes of the some to she said to her
# ==================================================
# Iteration #: 12
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.5421
# Generating from seed: raw.' 'wel
# raw.' 'well be and make and made on the course,' said the king and was goon it was her for the looked and she
# ==================================================
# Iteration #: 13
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.5250
# Generating from seed: n:-- 'you
# n:-- 'you arong the dormouse began the door again all the project gutenberg-tm to the project gutenberg-tm to
# ==================================================
# Iteration #: 14
# 1264/1264 [==============================] - 6s 4ms/step - loss: 1.5087
# Generating from seed: utenberg-t
# utenberg-tm electronic works of the some to see that she was not the some to see that she was not the some to
# ==================================================
# Iteration #: 15
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.4945
# Generating from seed:  only sobb
#  only sobbor a little she was a little she was a little she was a little she was a little she was a little she
# ==================================================
# Iteration #: 16
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.4811
# Generating from seed: terpillar.
# terpillar. 'it to glase with the white rabbit said to she was a little grow that it was the did they were get
# ==================================================
# Iteration #: 17
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.4697
# Generating from seed: r, and, ju
# r, and, just as she was so the project gutenberg-tm electronic works of courtered it was she was so the projec
# ==================================================
# Iteration #: 18
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.4589
# Generating from seed: ring but o
# ring but on the seaph the project gutenberg-tm electronic works the mock turtle said to her feet one the work
# ==================================================
# Iteration #: 19
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.4487
# Generating from seed:  to stay w
#  to stay work on the some to the some to the some to the some to the some to the some to the some to the some
# ==================================================
# Iteration #: 20
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.4391
# Generating from seed: ainly too
# ainly too the mock turtle said to herself this to see the ear the dormouse of the some to said the dormouse of
# ==================================================
# Iteration #: 21
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.4312
# Generating from seed: es and you
# es and you and the enger to sive the under the look again, and was not like the rabbit whither some to got it
# ==================================================
# Iteration #: 22
# 1264/1264 [==============================] - 6s 4ms/step - loss: 1.4234
# Generating from seed: , eager to
# , eager to the ching and done, and the ching and done, and the ching and done, and the ching and done, and the
# ==================================================
# Iteration #: 23
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.4147
# Generating from seed: ve flaming
# ve flaming the project gutenberg-tm electronic work is and made and she cauphed and she had not the cat the ca
# ==================================================
# Iteration #: 24
# 1264/1264 [==============================] - 6s 5ms/step - loss: 1.4086
# Generating from seed: s all roun
# s all round the king and again, and was not at all was the some to the same of the states and a little puzzled
